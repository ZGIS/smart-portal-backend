# %%
import rdflib
import pandas as pd
import numpy as np

g=rdflib.Graph()

# all issued and modified are actually from dcterms and only of date
# dcterms:issued "1999-07-02"^^<http://www.w3.org/2001/XMLSchema#date> ;
# dcterms:modified "2012-06-14"^^<http://www.w3.org/2001/XMLSchema#date> ;

def reformat(predicate):
    """
    # replace http://purl.org/dc/elements/1.1/type with dc:type ...first!
    # "dc:description", "dc:source", "dc:title", "dc:type", "dc:publisher",

    # replace http://purl.org/dc/elements/1.1/ rest with dcterms:
    # replace http://purl.org/dc/terms/ terms of course with dcterms:

    # replace http://www.w3.org/1999/02/22-rdf-syntax-ns# with rdf:
    # replace http://www.w3.org/2004/02/skos/core# with skos:

    # filter only for http://vocab.smart-project.info/papawai/term/ and remove
    # http://www.w3.org/2004/02/skos/core#inCollection skos:inCollection
    """
    if "http://purl.org/dc/elements/1.1/type" in predicate:
        return "dc:type"
    elif "http://purl.org/dc/elements/1.1/description" in predicate:
        return "dc:description"
    elif "http://purl.org/dc/elements/1.1/source" in predicate:
        return "dc:source"
    elif "http://purl.org/dc/elements/1.1/title" in predicate:
        return "dc:title"
    elif "http://purl.org/dc/elements/1.1/publisher" in predicate:
        return "dc:publisher"
    elif "http://purl.org/dc/elements/1.1/" in predicate:
        return predicate.replace("http://purl.org/dc/elements/1.1/", "dcterms:")
    elif "http://purl.org/dc/terms/" in predicate:
        return predicate.replace("http://purl.org/dc/terms/", "dcterms:")
    elif "http://www.w3.org/1999/02/22-rdf-syntax-ns#" in predicate:
        return predicate.replace("http://www.w3.org/1999/02/22-rdf-syntax-ns#", "rdf:")
    elif "http://www.w3.org/2004/02/skos/core#" in predicate:
        return predicate.replace("http://www.w3.org/2004/02/skos/core#", "skos:")

def generate(graph, col_id, hier):
    for s,p,o in graph:
        term_short = "http://vocab.smart-project.info/{}/{}/".format(col_id, hier)
        if term_short in s:
            newPredicate = reformat(p)
            if "skos:inCollection" not in newPredicate and "rdf:type" not in newPredicate:
                term_id = s.replace(term_short, "")
                # print(term_id,newPredicate,o)
                yield {'term': term_id, 'fields': newPredicate, 'data': o}

# g.parse('http://vocab.smart-project.info/spq-papawai/data', format="n3")
# collection = "papawai"
# hierarchy = "term"

# g.parse('http://vocab.smart-project.info/spq-ngmp/data', format="n3")
# collection = "ngmp"
# hierarchy = "phenomenon"

# g.parse('http://vocab.smart-project.info/spq-glossary/data', format="n3")
# collection = "glossary"
# hierarchy = "term"

g.parse('http://vocab.smart-project.info/spq-awahou/data', format="n3")
collection = "awahou"
hierarchy = "term"

rows = list(generate(g, collection, hierarchy))
df = pd.DataFrame(rows)
df.head(20)
# Out:
#                                                  data  \
# 0                                      GNS SR 2016/13
# 1                                                2016
# 2                                                  AL
# 3                                              Tephra
# 4                                                2016
# 5   The portion of stream flow that is not runoff ...
# 6                                                  AL
# 7                             Vapour phase alteration
# 8   An accumulation of groundwater that is above t...
# 9                                             Perched
# 10  Water located below the ground surface, e.g., ...
# 11  Material that is eroded or is reworked and dep...
# 12                          Taupo Volcanic Zone (TVZ)
# 13                                       Tritium (3H)
# 14                                                MAV
# 15                       Total dissolved solids (TDS)
# 16  The sum of all phosphorus compounds (reactive,...
# 17                                         Ignimbrite
# 18  The most probable outcome based on a set of fa...
# 19                                                 AL
#
#                            fields term
# 0   dcterms:bibliographicCitation   30
# 1               dcterms:available   50
# 2                    dc:publisher   47
# 3                      skos:label   73
# 4               dcterms:available    5
# 5                  dc:description    7
# 6                    dc:publisher   56
# 7                        dc:title   64
# 8                  dc:description   55
# 9                  skos:prefLabel   55
# 10                skos:definition   25
# 11                 dc:description    2
# 12                 skos:prefLabel   70
# 13                 skos:prefLabel   61
# 14                     skos:label   41
# 15                 skos:prefLabel   72
# 16                skos:definition   76
# 17                 skos:prefLabel   27
# 18                 dc:description   10
# 19                   dc:publisher   54

# %%
df['fields'].unique()
# Out:
# array(['dcterms:bibliographicCitation', 'dcterms:available',
#        'dc:publisher', 'skos:label', 'dc:description', 'dc:title',
#        'skos:prefLabel', 'skos:definition', 'dcterms:modified'],
#       dtype=object)

# %%
from rdflib import Literal


max_field_list = []
    
def new_field_name(row):
    dat = row['data']
    field = row['fields']
    if isinstance(dat, Literal):
            if dat.language is not None:
                field = field + "@" + dat.language
    max_field_list.append(field)
    return field

df['fields'] = df.apply(new_field_name, axis=1)

df.head()
# Out:
#              data                         fields term
# 0  GNS SR 2016/13  dcterms:bibliographicCitation   30
# 1            2016              dcterms:available   50
# 2              AL                   dc:publisher   47
# 3          Tephra                     skos:label   73
# 4            2016              dcterms:available    5

# %%
grouped = df.groupby('term')

# elem = grouped.get_group('12')
# len(elem['fields'].tolist())
# display(elem)

df_list = []
uniq_set = set(max_field_list)

for name, group in grouped:
    term_id = name
    dc_fields = group['fields'].tolist()
    dc_set = set(dc_fields)
    missing_cols = uniq_set.difference(dc_set)
    data_list = group['data'].tolist()
    data_tuple = [(x) for x in data_list]
    # display(data_tuple)
    this_df_data = [data_tuple] 
    this_df = pd.DataFrame.from_records(this_df_data, columns=dc_fields)
    this_df['term_id'] = int(name)
    for label in missing_cols:
        this_df[label] = np.nan
    this_df.reindex(index=this_df['term_id'])
    df_list.append(this_df)
    # with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #     display(this_df.head())

display(len(df_list))

cols = list(uniq_set)
cols.append('term_id')
start_df = pd.DataFrame.from_records([], columns=cols)
display('start shape: ' + str(start_df.shape))
display(start_df)

for gdf in df_list:
    start_df = pd.concat([start_df, gdf], join='outer', axis=0, ignore_index=True)
    # display(gdf.head())
    # start_df.append(gdf)

# full_df = pd.concat(df_list, axis=1 join='inner')
full_df = start_df.copy()

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(full_df.head(50))
# Out:
# 82
# 'start shape: (0, 10)'
# Empty DataFrame
# Columns: [dcterms:bibliographicCitation, dcterms:available, dc:publisher, dcterms:modified, dc:description, skos:prefLabel@en, dc:title, skos:label, skos:definition@en, term_id]
# Index: []
#                                        dc:description dc:publisher  \
# 0   Material that is eroded or is reworked and dep...           AL
# 1   The most probable outcome based on a set of fa...           AL
# 2   An area of land where surface water from rain,...           AL
# 3   A rock composed of broken fragments of mineral...           AL
# 4   Organic compounds that contains carbon, chlori...           AL
# 5   A large crater at the top of a volcano formed ...           AL
# 6   The lowest quantity of a substance that can be...           AL
# 7   An area of land where surface water from rain,...           AL
# 8   Oxygen that is dissolved in water. It is an im...           AL
# 9   Organic compounds that contains carbon, chlori...           AL
# 10  A measure of the dissolved (soluble) phosphoru...           AL
# 11  Material that is eroded or is reworked and dep...           AL
# 12  The lowest quantity of a substance that can be...           AL
# 13  Water located below the ground surface, e.g., ...           AL
# 14  A part of a rock body that can be differentiat...            v
# 15  A method used to estimate the discharge (volum...           AL
# 16  A hydrologic process where water moves downwar...           AL
# 17  Water located below the ground surface, e.g., ...           AL
# 18  A hydrologic process where water moves downwar...           AL
# 19  A pumice-dominated pyroclastic flow deposit fo...           AL
# 20  A pumice-dominated pyroclastic flow deposit fo...           AL
# 21                      Sediments deposited in lakes.           AL
# 22  A measure for the amount of ammonia, a polluta...           AL
# 23  Median Absolute Deviation, used in statistical...           AL
# 24                      Sediments deposited in lakes.           AL
# 25  Median Absolute Deviation, used in statistical...           AL
# 26  Oxygen that is dissolved in water. It is an im...           AL
# 27  A measure of a material's ability to conduct e...            v
# 28  The sum of evaporation and plant transpiration...           AL
# 29  A measure of the dissolved (soluble) phosphoru...           AL
# 30  A part of a rock body that can be differentiat...            v
# 31  A measure of a material's ability to conduct e...            v
# 32  A method used to estimate the discharge (volum...           AL
# 33  A measure for the amount of ammonia, a polluta...           AL
# 34  The sum of evaporation and plant transpiration...           AL
# 35  Maximum Acceptable Value for particular water ...           AL
# 36  Maximum Acceptable Value for particular water ...           AL
# 37  The average amount of time that a water molecu...           AL
# 38  The average amount of time that a water molecu...           AL
# 39  Name of the geological period that occurred 25...           AL
# 40  Name of the geological period that occurred 25...           AL
# 41  National Groundwater Monitoring Programme, inv...           AL
# 42  National Groundwater Monitoring Programme, inv...           AL
# 43  A nutrient in water that is associated with la...           AL
# 44  The portion of stream flow that is not runoff ...           AL
# 45  Nephelometric Turbidity Units, a unit used to ...           AL
# 46  A nutrient in water that is associated with la...           AL
# 47  An area in the North Island, within the TVZ, t...           AL
# 48  Nephelometric Turbidity Units, a unit used to ...           AL
# 49  An area in the North Island, within the TVZ, t...           AL
#
#                                dc:title dcterms:available  \
# 0                     Alluvial sediment              2016
# 1                         Best-estimate              2016
# 2                             Catchment              2016
# 3                               Breccia              2016
# 4            Chlorofluorocarbons (CFCs)              2016
# 5                         Caldera Basin              2016
# 20  A pumice-dominated pyroclastic flow deposit fo...
# 21                      Sediments deposited in lakes.
# 22  A measure for the amount of ammonia, a polluta...
# 23  Median Absolute Deviation, used in statistical...
# 24                      Sediments deposited in lakes.
# 25  Median Absolute Deviation, used in statistical...
# 26  Oxygen that is dissolved in water. It is an im...
# 27  A measure of a material's ability to conduct e...
# 28  The sum of evaporation and plant transpiration...
# 29  A measure of the dissolved (soluble) phosphoru...
# 30  A part of a rock body that can be differentiat...
# 31  A measure of a material's ability to conduct e...
# 32  A method used to estimate the discharge (volum...
# 33  A measure for the amount of ammonia, a polluta...
# 34  The sum of evaporation and plant transpiration...
# 35  Maximum Acceptable Value for particular water ...
# 36  Maximum Acceptable Value for particular water ...
# 37  The average amount of time that a water molecu...
# 38  The average amount of time that a water molecu...
# 39  Name of the geological period that occurred 25...
# 40  Name of the geological period that occurred 25...
# 41  National Groundwater Monitoring Programme, inv...
# 42  National Groundwater Monitoring Programme, inv...
# 43  A nutrient in water that is associated with la...
# 44  The portion of stream flow that is not runoff ...
# 45  Nephelometric Turbidity Units, a unit used to ...
# 46  A nutrient in water that is associated with la...
# 47  An area in the North Island, within the TVZ, t...
# 48  Nephelometric Turbidity Units, a unit used to ...
# 49  An area in the North Island, within the TVZ, t...
#
#                              skos:label                    skos:prefLabel@en  \
# 0                     Alluvial sediment                    Alluvial sediment
# 1                         Best-estimate                        Best-estimate
# 2                             Catchment                            Catchment
# 3                               Breccia                              Breccia
# 4            Chlorofluorocarbons (CFCs)           Chlorofluorocarbons (CFCs)
# 5                         Caldera Basin                        Caldera Basin
# 6                       Detection limit                      Detection limit
# 7                             Catchment                            Catchment
# 8                 Dissolved Oxygen (DO)                Dissolved Oxygen (DO)
# 9            Chlorofluorocarbons (CFCs)           Chlorofluorocarbons (CFCs)
# 10  Dissolved Reactive Phosphorus (DRP)  Dissolved Reactive Phosphorus (DRP)
# 11                    Alluvial sediment                    Alluvial sediment
# 12                      Detection limit                      Detection limit
# 13                          Groundwater                          Groundwater
# 14                               Facies                               Facies
# 15                              Gauging                              Gauging
# 16                 Groundwater recharge                 Groundwater recharge
# 17                          Groundwater                          Groundwater
# 18                 Groundwater recharge                 Groundwater recharge
# 19                           Ignimbrite                           Ignimbrite
# 20                           Ignimbrite                           Ignimbrite
# 21                 Lacustrine sediments                 Lacustrine sediments
# 22          Ammoniacal-nitrogen (NH3-N)          Ammoniacal-nitrogen (NH3-N)
# 23                                  MAD                                  MAD
# 24                 Lacustrine sediments                 Lacustrine sediments
# 25                                  MAD                                  MAD
# 26                Dissolved Oxygen (DO)                Dissolved Oxygen (DO)
# 27         Electrical conductivity (EC)         Electrical conductivity (EC)
# 28                   Evapotranspiration                   Evapotranspiration
# 29  Dissolved Reactive Phosphorus (DRP)  Dissolved Reactive Phosphorus (DRP)
# 30                               Facies                               Facies
# 31         Electrical conductivity (EC)         Electrical conductivity (EC)
# 32                              Gauging                              Gauging
# 33          Ammoniacal-nitrogen (NH3-N)          Ammoniacal-nitrogen (NH3-N)
# 34                   Evapotranspiration                   Evapotranspiration
# 35                                  MAV                                  MAV
# 36                                  MAV                                  MAV
# 37            Mean Residence Time (MRT)            Mean Residence Time (MRT)
# 38            Mean Residence Time (MRT)            Mean Residence Time (MRT)
# 39                             Mesozoic                             Mesozoic
# 40                             Mesozoic                             Mesozoic
# 41                                 NGMP                                 NGMP
# 42                                 NGMP                                 NGMP
# 43             Nitrate-nitrogen (NO3-N)             Nitrate-nitrogen (NO3-N)
# 44                             Baseflow                             Baseflow
# 45                                  NTU                                  NTU
# 46             Nitrate-nitrogen (NO3-N)             Nitrate-nitrogen (NO3-N)
# 47      Okataina Volcanic Complex (OVC)      Okataina Volcanic Complex (OVC)
# 48                                  NTU                                  NTU
# 49      Okataina Volcanic Complex (OVC)      Okataina Volcanic Complex (OVC)
#
#    term_id
# 0        1
# 1       10
# 2       11
# 3       12
# 4       13
# 5       14
# 6       15
# 7       16
# 8       17
# 9       18
# 10      19
# 11       2
# 12      20
# 13      21
# 14      22
# 15      23
# 16      24
# 17      25
# 18      26
# 19      27
# 20      28
# 21      29
# 22       3
# 23      30
# 24      31
# 25      32
# 26      33
# 27      34
# 28      35
# 29      36
# 30      37
# 31      38
# 32      39
# 33       4
# 34      40
# 35      41
# 36      42
# 37      43
# 38      44
# 39      45
# 40      46
# 41      47
# 42      48
# 43      49
# 44       5
# 45      50
# 46      51
# 47      52
# 48      53
# 49      54

# %%
fields = []
for t in cols:
    if "dc:" in t:
        ln = t.replace("dc:", "http://purl.org/dc/elements/1.1/")
        ln = ln.replace("@en", "")
        ln = ln.replace("@mi", "")
        fields.append({'element': t, 'description': ln})
    elif "dcterms:" in t:
        ln = t.replace("dcterms:", "http://purl.org/dc/terms/")
        ln = ln.replace("@en", "")
        ln = ln.replace("@mi", "")
        fields.append({'element': t, 'description': ln})
    elif "skos:" in t:
        ln = t.replace("skos:", "http://www.w3.org/2004/02/skos/core#")
        ln = ln.replace("@en", "")
        ln = ln.replace("@mi", "")
        fields.append({'element': t, 'description': ln})
        
df2 = pd.DataFrame.from_dict(fields)
df2.head()
# Out:
#                                       description  \
# 0  http://purl.org/dc/terms/bibliographicCitation
# 1              http://purl.org/dc/terms/available
# 2       http://purl.org/dc/elements/1.1/publisher
# 3               http://purl.org/dc/terms/modified
# 4     http://purl.org/dc/elements/1.1/description
#
#                          element
# 0  dcterms:bibliographicCitation
# 1              dcterms:available
# 2                   dc:publisher
# 3               dcterms:modified
# 4                 dc:description

# %%
writer = pd.ExcelWriter(collection + '.xlsx')
full_df.to_excel(writer,'Terms')
df2.to_excel(writer,'TermsMeaning')
writer.save()
writer.close()
